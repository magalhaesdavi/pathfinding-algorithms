# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
output_df = pd.read_csv(r'C:\Users\davim\OneDrive\Documentos\Projects\GitHub\Trabalho-de-IA\trabalhoIA\outputs\results.csv')

# %%
output_df.head()
# Out:
#       algorithm                                           solution   depth  \
# 0  Backtracking   'NorthKatherinehaven'->'Brittanytown'->'North...      17
# 1  Backtracking   'NorthKatherinehaven'->'Brittanytown'->'North...      17
# 2  Backtracking   'NorthKatherinehaven'->'Brittanytown'->'North...      17
# 3  Backtracking   'NorthKatherinehaven'->'Brittanytown'->'North...      17
# 4  Backtracking   'NorthKatherinehaven'->'Brittanytown'->'North...      17
#
#       cost   expanded_nodes   visited_nodes   average_branching_factor  \
# 0  541.338               17              18                        1.0
# 1  541.338               17              18                        1.0
# 2  541.338               17              18                        1.0
# 3  541.338               17              18                        1.0
# 4  541.338               17              18                        1.0
#
#     execution_time    result   n
# 0         0.000091   SUCCESS  25
# 1         0.000097   SUCCESS  25
# 2         0.000087   SUCCESS  25
# 3         0.000163   SUCCESS  25
# 4         0.000150   SUCCESS  25

# %%
grouped = output_df[['algorithm', ' depth', ' cost', ' expanded_nodes',
       ' visited_nodes', ' average_branching_factor', ' execution_time',
       ' n']].groupby(['algorithm', ' n']).mean()
grouped.reset_index(inplace = True)
grouped
# Out:
#        algorithm    n   depth       cost   expanded_nodes   visited_nodes  \
# 0          Astar   25       7    260.778               21              25
# 1          Astar   50      11   2139.695               32              42
# 2          Astar  100      16   4046.594               66              79
# 3            BFS   25       7    302.152               21              25
# 4            BFS   50       9   2347.273               45              49
# 5            BFS  100      13   4381.042               87              88
# 6   Backtracking   25      17    541.338               17              18
# 7   Backtracking   50      19   4199.785               20              21
# 8   Backtracking  100      24   8267.924               70              71
# 9            DFS   25       9    290.479               38              24
# 10           DFS   50      24   5113.458               55              45
# 11           DFS  100      35  10150.684               86              68
# 12        Greedy   25       7    260.778               11              11
# 13        Greedy   50      11   2308.493               21              18
# 14        Greedy  100      17   4720.892               17              18
# 15       IDAstar   25       8    261.702              401              24
# 16       IDAstar   50      13   3062.342             1336              27
# 17       IDAstar  100      18   5429.601             3939              39
# 18           UCS   25       7    260.778              102              25
# 19           UCS   50      11   2139.695              200              50
# 20           UCS  100      16   4046.594              357              87
#
#      average_branching_factor   execution_time
# 0                    2.142857         0.000346
# 1                    2.312500         0.000538
# 2                    2.272727         0.000809
# 3                    4.095238         0.000132
# 4                    4.022222         0.000238
# 5                    4.103448         0.000744
# 6                    1.000000         0.000118
# 7                    1.000000         0.000113
# 8                    1.000000         0.001017
# 9                    4.657895         0.000237
# 10                   4.000000         0.000337
# 11                   3.965116         0.000633
# 12                   3.272727         0.000155
# 13                   3.857143         0.000232
# 14                   4.529412         0.000478
# 15                   2.142857         0.002248
# 16                   2.312500         0.008316
# 17                   2.272727         0.027162
# 18                   4.657895         0.000810
# 19                   4.000000         0.001668
# 20                   3.965116         0.003062

# %%
g = sns.relplot(x = " n", y = ' execution_time', data = grouped, hue = 'algorithm', kind = "line")
g.savefig("execution_time1.png")

# %%
sns.relplot(x = " n", y = ' execution_time', data = grouped.query("algorithm != 'IDAstar'"), hue = 'algorithm', kind = "line")

# %%
sns.relplot(x = " n", y = ' cost', data = grouped, hue = 'algorithm', kind = "line")

# %%
sns.relplot(x = " n", y = ' cost', data = grouped.query("algorithm == 'Astar'"), hue = 'algorithm', kind = "line")
